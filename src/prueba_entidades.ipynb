# %% [markdown]
# # La Tienda de Aurelion
#
# ## Descripcion del proyecto
# Este proyecto es una simulación de una tienda. La tienda cuenta con clientes, productos y ventas. El objetivo es simular el flujo de ventas y gestionar los clientes y productos.

# %%
## Inicializar Applicacion

from app_state import App

app = App()

# %%
## Extraccion de los primeros 5 Clientes de la base de datos
clientes_serv = app.clientes_service

for cliente in clientes_serv.get_all()[:5]:
    print(cliente)
# Out:
# ClienteModel(id_cliente=1, nombre_cliente='Mariana Lopez', email='mariana.lopez@mail.com', ciudad='Carlos Paz', fecha_alta='PUNILLA', departamento='2023-01-01')
# ClienteModel(id_cliente=2, nombre_cliente='Nicolas Rojas', email='nicolas.rojas@mail.com', ciudad='Carlos Paz', fecha_alta='PUNILLA', departamento='2023-01-02')
# ClienteModel(id_cliente=3, nombre_cliente='Hernan Martinez', email='hernan.martinez@mail.com', ciudad='Rio Cuarto', fecha_alta='RIO CUARTO', departamento='2023-01-03')
# ClienteModel(id_cliente=4, nombre_cliente='Uma Martinez', email='uma.martinez@mail.com', ciudad='Carlos Paz', fecha_alta='PUNILLA', departamento='2023-01-04')
# ClienteModel(id_cliente=5, nombre_cliente='Agustina Flores', email='agustina.flores@mail.com', ciudad='Cordoba', fecha_alta='CAPITAL', departamento='2023-01-05')

# %%
## Obtener un cliente por ID 1
cliente_1 = clientes_serv.buscar_por_id(1)

print(cliente_1.total_ventas())
# Out:
# {'importe': 72448.0, 'cantidad_ventas': 2, 'tarjeta': 36035.0, 'qr': 0, 'transferencia': 36413.0, 'efectivo': 0}

# %%
## set de ciudades

ciudades = clientes_serv.repository.ciudades

print(ciudades)
# Out:
# ['Carlos Paz', 'Rio Cuarto', 'Cordoba', 'Villa Maria', 'Alta Gracia', 'Mendiolaza']

# %%
## Extraccion de primeras 5 Ventas de la base de datos

venta_serv = app.ventas_service

for venta in venta_serv.get_all()[:5]:
    print(venta)
# Out:
# VentaModel(id_venta=12, fecha='2024-06-28', id_cliente=96, nombre_cliente='Rocio Gonzalez', email='rocio.gonzalez@mail.com', medio_pago='efectivo')
# VentaModel(id_venta=68, fecha='2024-06-28', id_cliente=27, nombre_cliente='Tomas Castro', email='tomas.castro@mail.com', medio_pago='qr')
# VentaModel(id_venta=15, fecha='2024-06-27', id_cliente=56, nombre_cliente='Bruno Diaz', email='bruno.diaz@mail.com', medio_pago='transferencia')
# VentaModel(id_venta=36, fecha='2024-06-25', id_cliente=5, nombre_cliente='Agustina Flores', email='agustina.flores@mail.com', medio_pago='tarjeta')
# VentaModel(id_venta=88, fecha='2024-06-21', id_cliente=37, nombre_cliente='Martina Perez', email='martina.perez@mail.com', medio_pago='efectivo')

# %%
## Obtener una venta por ID 2
venta_2 = venta_serv.get_by_id_venta(2)
print(venta_2)
# Out:
# VentaModel(id_venta=2, fecha='2024-03-17', id_cliente=49, nombre_cliente='Olivia Gomez', email='olivia.gomez@mail.com', medio_pago='qr')

# %%
## Si se prefiere en Formato JSON (muy util para APIs web)
print(venta_2.to_json())
# Out:
# {
#     "id_venta": 2,
#     "fecha": "2024-03-17",
#     "id_cliente": 49,
#     "nombre_cliente": "Olivia Gomez",
#     "email": "olivia.gomez@mail.com",
#     "medio_pago": "qr",
#     "detalle": [
#         {
#             "id_venta": 2394.0,
#             "id_producto": 2,
#             "nombre_producto": 82,
#             "cantidad": null,
#             "precio_unitario": 5,
#             "importe": 11970.0
#         },
#         {
#             "id_venta": 469.0,
#             "id_producto": 2,
#             "nombre_producto": 39,
#             "cantidad": null,
#             "precio_unitario": 5,
#             "importe": 2345.0
#         },
#         {
#             "id_venta": 4061.0,
#             "id_producto": 2,
#             "nombre_producto": 70,
#             "cantidad": null,
#             "precio_unitario": 2,
#             "importe": 8122.0
#         },
#         {
#             "id_venta": 2069.0,
#             "id_producto": 2,
#             "nombre_producto": 22,
#             "cantidad": null,
#             "precio_unitario": 1,
#             "importe": 2069.0
#         },
#         {
#             "id_venta": 2420.0,
#             "id_producto": 2,
#             "nombre_producto": 79,
#             "cantidad": null,
#             "precio_unitario": 4,
#             "importe": 9680.0
#         }
#     ],
#     "importe": 34186.0
# }

# %%
## Extracción de los primeros 5 productos de la base de datos

producto_serv = app.productos_service

for producto in producto_serv.get_all()[:5]:
    print(producto)

# %%
producto1 = producto_serv.get_by_id(1)

print(producto1.ventas)
print(producto1.total_vendido())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 producto1 = producto_serv.get_by_id(1)
#       3 print(producto1.ventas)
#       4 print(producto1.total_vendido())
#
# File ~/Documents/guayerd/aurelion/src/modules/productos/producto_service.py:21, in ProductoService.get_by_id(self, id_producto)
#      15 def get_by_id(self, id_producto: int) -> ProductoModel:
#      16     """
#      17     Retorna el producto con el id especificado.
#      18
#      19     :param id: El id del producto a buscar.
#      20     """
# ---> 21     return self._repository.get_by_id(id_producto)
#
# File ~/Documents/guayerd/aurelion/src/modules/productos/productos_repository.py:23, in ProductosRepository.get_by_id(self, id)
#      19 def get_by_id(self, id: int) -> ProductoModel:
#      20     """
#      21     Returns the product with the given id.
#      22     """
# ---> 23     return ProductoModel(*self._dao.get_by_id(id))
#
# TypeError: modules.productos.producto_model.ProductoModel() argument after * must be an iterable, not NoneType

# %%
ventas_ciudades = venta_serv.get_ventas_por_ciudad()
print(ventas_ciudades)
# Out:
# [{'ciudad': 'RIO CUARTO', 'departamento': 'RIO CUARTO', 'importe': 792203.0}, {'ciudad': 'ALTA GRACIA', 'departamento': 'SANTA MARIA', 'importe': 481504.0}, {'ciudad': 'CORDOBA', 'departamento': 'CAPITAL', 'importe': 481482.0}, {'ciudad': 'CARLOS PAZ', 'departamento': 'PUNILLA', 'importe': 353852.0}, {'ciudad': 'VILLA MARIA', 'departamento': 'GENERAL SAN MARTIN', 'importe': 313350.0}, {'ciudad': 'MENDIOLAZA', 'departamento': 'COLON', 'importe': 229026.0}]
