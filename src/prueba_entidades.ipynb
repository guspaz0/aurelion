# %% [markdown]
# # La Tienda de Aurelion
#
# ## Descripcion del proyecto
# Este proyecto es una simulación de una tienda. La tienda cuenta con clientes, productos y ventas. El objetivo es simular el flujo de ventas y gestionar los clientes y productos.

# %%
## Inicializar Applicacion

from app_state import App

app = App()

# %%
## Extraccion de los primeros 5 Clientes de la base de datos
clientes_serv = app.clientes_service

for cliente in clientes_serv.get_all()[:5]:
    print(cliente)
# Out:
# ClienteModel(id_cliente=1, nombre_cliente='Mariana Lopez', email='mariana.lopez@mail.com', ciudad='Carlos Paz', fecha_alta='PUNILLA', departamento='2023-01-01', ventas=[VentaModel(id_venta=54, fecha=datetime.datetime(2024, 3, 26, 0, 0), id_cliente=1, nombre_cliente='Mariana Lopez', email='mariana.lopez@mail.com', medio_pago='tarjeta', ciudad='Carlos Paz', importe=36035.0, detalle=[DetalleVentaModel(id_venta=54, id_producto=8, nombre_producto='Energética Nitro 500ml', cantidad=3, precio_unitario=4218.0, importe=12654.0, fecha=datetime.datetime(2024, 3, 26, 0, 0)), DetalleVentaModel(id_venta=54, id_producto=18, nombre_producto='Queso Rallado 150g', cantidad=2, precio_unitario=3444.0, importe=6888.0, fecha=datetime.datetime(2024, 3, 26, 0, 0)), DetalleVentaModel(id_venta=54, id_producto=65, nombre_producto='Cerveza Rubia 1L', cantidad=1, precio_unitario=2423.0, importe=2423.0, fecha=datetime.datetime(2024, 3, 26, 0, 0)), DetalleVentaModel(id_venta=54, id_producto=91, nombre_producto='Desodorante Aerosol', cantidad=3, precio_unitario=4690.0, importe=14070.0, fecha=datetime.datetime(2024, 3, 26, 0, 0))]), VentaModel(id_venta=105, fecha=datetime.datetime(2024, 2, 6, 0, 0), id_cliente=1, nombre_cliente='Mariana Lopez', email='mariana.lopez@mail.com', medio_pago='transferencia', ciudad='Carlos Paz', importe=36413.0, detalle=[DetalleVentaModel(id_venta=105, id_producto=4, nombre_producto='Fanta Naranja 1.5L', cantidad=4, precio_unitario=2033.0, importe=8132.0, fecha=datetime.datetime(2024, 2, 6, 0, 0)), DetalleVentaModel(id_venta=105, id_producto=13, nombre_producto='Té Verde 20 saquitos', cantidad=2, precio_unitario=2383.0, importe=4766.0, fecha=datetime.datetime(2024, 2, 6, 0, 0)), DetalleVentaModel(id_venta=105, id_producto=43, nombre_producto='Salsa de Tomate 500g', cantidad=5, precio_unitario=887.0, importe=4435.0, fecha=datetime.datetime(2024, 2, 6, 0, 0)), DetalleVentaModel(id_venta=105, id_producto=58, nombre_producto='Caramelos Masticables', cantidad=2, precio_unitario=4752.0, importe=9504.0, fecha=datetime.datetime(2024, 2, 6, 0, 0)), DetalleVentaModel(id_venta=105, id_producto=82, nombre_producto='Aceitunas Negras 200g', cantidad=4, precio_unitario=2394.0, importe=9576.0, fecha=datetime.datetime(2024, 2, 6, 0, 0))])])
# ClienteModel(id_cliente=2, nombre_cliente='Nicolas Rojas', email='nicolas.rojas@mail.com', ciudad='Carlos Paz', fecha_alta='PUNILLA', departamento='2023-01-02', ventas=[VentaModel(id_venta=16, fecha=datetime.datetime(2024, 4, 12, 0, 0), id_cliente=2, nombre_cliente='Nicolas Rojas', email='nicolas.rojas@mail.com', medio_pago='efectivo', ciudad='Carlos Paz', importe=22150.0, detalle=[DetalleVentaModel(id_venta=16, id_producto=35, nombre_producto='Barrita de Cereal 30g', cantidad=5, precio_unitario=4430.0, importe=22150.0, fecha=datetime.datetime(2024, 4, 12, 0, 0))])])
# ClienteModel(id_cliente=3, nombre_cliente='Hernan Martinez', email='hernan.martinez@mail.com', ciudad='Rio Cuarto', fecha_alta='RIO CUARTO', departamento='2023-01-03', ventas=[VentaModel(id_venta=115, fecha=datetime.datetime(2024, 2, 16, 0, 0), id_cliente=3, nombre_cliente='Hernan Martinez', email='hernan.martinez@mail.com', medio_pago='transferencia', ciudad='Rio Cuarto', importe=33310.0, detalle=[DetalleVentaModel(id_venta=115, id_producto=17, nombre_producto='Queso Cremoso 500g', cantidad=4, precio_unitario=4834.0, importe=19336.0, fecha=datetime.datetime(2024, 2, 16, 0, 0)), DetalleVentaModel(id_venta=115, id_producto=84, nombre_producto='Queso Azul 150g', cantidad=2, precio_unitario=1645.0, importe=3290.0, fecha=datetime.datetime(2024, 2, 16, 0, 0)), DetalleVentaModel(id_venta=115, id_producto=95, nombre_producto='Mascarilla Capilar', cantidad=4, precio_unitario=1581.0, importe=6324.0, fecha=datetime.datetime(2024, 2, 16, 0, 0)), DetalleVentaModel(id_venta=115, id_producto=97, nombre_producto='Limpiavidrios 500ml', cantidad=5, precio_unitario=872.0, importe=4360.0, fecha=datetime.datetime(2024, 2, 16, 0, 0))])])
# ClienteModel(id_cliente=4, nombre_cliente='Uma Martinez', email='uma.martinez@mail.com', ciudad='Carlos Paz', fecha_alta='PUNILLA', departamento='2023-01-04', ventas=[VentaModel(id_venta=None, fecha=None, id_cliente=None, nombre_cliente=None, email=None, medio_pago=None, ciudad=None, importe=None, detalle=[])])
# ClienteModel(id_cliente=5, nombre_cliente='Agustina Flores', email='agustina.flores@mail.com', ciudad='Cordoba', fecha_alta='CAPITAL', departamento='2023-01-05', ventas=[VentaModel(id_venta=36, fecha=datetime.datetime(2024, 6, 25, 0, 0), id_cliente=5, nombre_cliente='Agustina Flores', email='agustina.flores@mail.com', medio_pago='tarjeta', ciudad='Cordoba', importe=11832.0, detalle=[DetalleVentaModel(id_venta=36, id_producto=48, nombre_producto='Porotos Negros 500g', cantidad=2, precio_unitario=4462.0, importe=8924.0, fecha=datetime.datetime(2024, 6, 25, 0, 0)), DetalleVentaModel(id_venta=36, id_producto=50, nombre_producto='Azúcar 1kg', cantidad=4, precio_unitario=727.0, importe=2908.0, fecha=datetime.datetime(2024, 6, 25, 0, 0))]), VentaModel(id_venta=39, fecha=datetime.datetime(2024, 3, 5, 0, 0), id_cliente=5, nombre_cliente='Agustina Flores', email='agustina.flores@mail.com', medio_pago='efectivo', ciudad='Cordoba', importe=45142.0, detalle=[DetalleVentaModel(id_venta=39, id_producto=22, nombre_producto='Medialunas de Manteca', cantidad=2, precio_unitario=2069.0, importe=4138.0, fecha=datetime.datetime(2024, 3, 5, 0, 0)), DetalleVentaModel(id_venta=39, id_producto=44, nombre_producto='Arroz Largo Fino 1kg', cantidad=4, precio_unitario=2979.0, importe=11916.0, fecha=datetime.datetime(2024, 3, 5, 0, 0)), DetalleVentaModel(id_venta=39, id_producto=58, nombre_producto='Caramelos Masticables', cantidad=4, precio_unitario=4752.0, importe=19008.0, fecha=datetime.datetime(2024, 3, 5, 0, 0)), DetalleVentaModel(id_venta=39, id_producto=81, nombre_producto='Aceitunas Verdes 200g', cantidad=4, precio_unitario=2520.0, importe=10080.0, fecha=datetime.datetime(2024, 3, 5, 0, 0))]), VentaModel(id_venta=49, fecha=datetime.datetime(2024, 6, 2, 0, 0), id_cliente=5, nombre_cliente='Agustina Flores', email='agustina.flores@mail.com', medio_pago='efectivo', ciudad='Cordoba', importe=38660.0, detalle=[DetalleVentaModel(id_venta=49, id_producto=18, nombre_producto='Queso Rallado 150g', cantidad=3, precio_unitario=3444.0, importe=10332.0, fecha=datetime.datetime(2024, 6, 2, 0, 0)), DetalleVentaModel(id_venta=49, id_producto=21, nombre_producto='Pan Lactal Integral', cantidad=4, precio_unitario=272.0, importe=1088.0, fecha=datetime.datetime(2024, 6, 2, 0, 0)), DetalleVentaModel(id_venta=49, id_producto=59, nombre_producto='Chicle Menta', cantidad=2, precio_unitario=3612.0, importe=7224.0, fecha=datetime.datetime(2024, 6, 2, 0, 0)), DetalleVentaModel(id_venta=49, id_producto=59, nombre_producto='Chicle Menta', cantidad=4, precio_unitario=3612.0, importe=14448.0, fecha=datetime.datetime(2024, 6, 2, 0, 0)), DetalleVentaModel(id_venta=49, id_producto=85, nombre_producto='Jugo en Polvo Naranja', cantidad=3, precio_unitario=1856.0, importe=5568.0, fecha=datetime.datetime(2024, 6, 2, 0, 0))]), VentaModel(id_venta=52, fecha=datetime.datetime(2024, 5, 10, 0, 0), id_cliente=5, nombre_cliente='Agustina Flores', email='agustina.flores@mail.com', medio_pago='tarjeta', ciudad='Cordoba', importe=36524.0, detalle=[DetalleVentaModel(id_venta=52, id_producto=9, nombre_producto='Yerba Mate Suave 1kg', cantidad=4, precio_unitario=3878.0, importe=15512.0, fecha=datetime.datetime(2024, 5, 10, 0, 0)), DetalleVentaModel(id_venta=52, id_producto=38, nombre_producto='Mermelada de Frutilla 400g', cantidad=3, precio_unitario=1584.0, importe=4752.0, fecha=datetime.datetime(2024, 5, 10, 0, 0)), DetalleVentaModel(id_venta=52, id_producto=81, nombre_producto='Aceitunas Verdes 200g', cantidad=5, precio_unitario=2520.0, importe=12600.0, fecha=datetime.datetime(2024, 5, 10, 0, 0)), DetalleVentaModel(id_venta=52, id_producto=83, nombre_producto='Queso Untable 190g', cantidad=2, precio_unitario=1830.0, importe=3660.0, fecha=datetime.datetime(2024, 5, 10, 0, 0))])])

# %%
## Obtener un cliente por ID 1
cliente_1 = clientes_serv.buscar_por_id(1)

print(cliente_1.ventas[0])
# Out:
# VentaModel(id_venta=54, fecha=datetime.datetime(2024, 3, 26, 0, 0), id_cliente=1, nombre_cliente='Mariana Lopez', email='mariana.lopez@mail.com', medio_pago='tarjeta', ciudad='Carlos Paz', importe=36035.0, detalle=[DetalleVentaModel(id_venta=54, id_producto=8, nombre_producto='Energética Nitro 500ml', cantidad=3, precio_unitario=4218.0, importe=12654.0, fecha=datetime.datetime(2024, 3, 26, 0, 0)), DetalleVentaModel(id_venta=54, id_producto=18, nombre_producto='Queso Rallado 150g', cantidad=2, precio_unitario=3444.0, importe=6888.0, fecha=datetime.datetime(2024, 3, 26, 0, 0)), DetalleVentaModel(id_venta=54, id_producto=65, nombre_producto='Cerveza Rubia 1L', cantidad=1, precio_unitario=2423.0, importe=2423.0, fecha=datetime.datetime(2024, 3, 26, 0, 0)), DetalleVentaModel(id_venta=54, id_producto=91, nombre_producto='Desodorante Aerosol', cantidad=3, precio_unitario=4690.0, importe=14070.0, fecha=datetime.datetime(2024, 3, 26, 0, 0))])

# %%
## set de ciudades

ciudades = app.ventas_service.ciudades

print(ciudades)
# Out:
# ['Carlos Paz', 'Rio Cuarto', 'Cordoba', 'Villa Maria', 'Alta Gracia', 'Mendiolaza']

# %%
## Extraccion de primeras 5 Ventas de la base de datos

venta_serv = app.ventas_service

for venta in venta_serv.get_all()[:5]:
    print(venta)
# Out:
# VentaModel(id_venta=1, fecha=datetime.datetime(2024, 6, 19, 0, 0), id_cliente=62, nombre_cliente='Guadalupe Romero', email='guadalupe.romero@mail.com', medio_pago='tarjeta', ciudad='Carlos Paz', importe=2902.0, detalle=[DetalleVentaModel(id_venta=1, id_producto=90, nombre_producto='Toallas Húmedas x50', cantidad=1, precio_unitario=2902.0, importe=2902.0, fecha=datetime.datetime(2024, 6, 19, 0, 0))])
# VentaModel(id_venta=2, fecha=datetime.datetime(2024, 3, 17, 0, 0), id_cliente=49, nombre_cliente='Olivia Gomez', email='olivia.gomez@mail.com', medio_pago='qr', ciudad='Rio Cuarto', importe=34186.0, detalle=[DetalleVentaModel(id_venta=2, id_producto=22, nombre_producto='Medialunas de Manteca', cantidad=1, precio_unitario=2069.0, importe=2069.0, fecha=datetime.datetime(2024, 3, 17, 0, 0)), DetalleVentaModel(id_venta=2, id_producto=39, nombre_producto='Helado Vainilla 1L', cantidad=5, precio_unitario=469.0, importe=2345.0, fecha=datetime.datetime(2024, 3, 17, 0, 0)), DetalleVentaModel(id_venta=2, id_producto=70, nombre_producto='Fernet 750ml', cantidad=2, precio_unitario=4061.0, importe=8122.0, fecha=datetime.datetime(2024, 3, 17, 0, 0)), DetalleVentaModel(id_venta=2, id_producto=79, nombre_producto='Hamburguesas Congeladas x4', cantidad=4, precio_unitario=2420.0, importe=9680.0, fecha=datetime.datetime(2024, 3, 17, 0, 0)), DetalleVentaModel(id_venta=2, id_producto=82, nombre_producto='Aceitunas Negras 200g', cantidad=5, precio_unitario=2394.0, importe=11970.0, fecha=datetime.datetime(2024, 3, 17, 0, 0))])
# VentaModel(id_venta=3, fecha=datetime.datetime(2024, 1, 13, 0, 0), id_cliente=20, nombre_cliente='Tomas Acosta', email='tomas.acosta@mail.com', medio_pago='tarjeta', ciudad='Rio Cuarto', importe=19558.0, detalle=[DetalleVentaModel(id_venta=3, id_producto=2, nombre_producto='Pepsi 1.5L', cantidad=2, precio_unitario=4973.0, importe=9946.0, fecha=datetime.datetime(2024, 1, 13, 0, 0)), DetalleVentaModel(id_venta=3, id_producto=9, nombre_producto='Yerba Mate Suave 1kg', cantidad=2, precio_unitario=3878.0, importe=7756.0, fecha=datetime.datetime(2024, 1, 13, 0, 0)), DetalleVentaModel(id_venta=3, id_producto=85, nombre_producto='Jugo en Polvo Naranja', cantidad=1, precio_unitario=1856.0, importe=1856.0, fecha=datetime.datetime(2024, 1, 13, 0, 0))])
# VentaModel(id_venta=4, fecha=datetime.datetime(2024, 2, 27, 0, 0), id_cliente=36, nombre_cliente='Martina Molina', email='martina.molina@mail.com', medio_pago='transferencia', ciudad='Mendiolaza', importe=15966.0, detalle=[DetalleVentaModel(id_venta=4, id_producto=4, nombre_producto='Fanta Naranja 1.5L', cantidad=2, precio_unitario=2033.0, importe=4066.0, fecha=datetime.datetime(2024, 2, 27, 0, 0)), DetalleVentaModel(id_venta=4, id_producto=23, nombre_producto='Bizcochos Salados', cantidad=5, precio_unitario=2380.0, importe=11900.0, fecha=datetime.datetime(2024, 2, 27, 0, 0))])
# VentaModel(id_venta=5, fecha=datetime.datetime(2024, 6, 11, 0, 0), id_cliente=56, nombre_cliente='Bruno Diaz', email='bruno.diaz@mail.com', medio_pago='tarjeta', ciudad='Rio Cuarto', importe=16360.0, detalle=[DetalleVentaModel(id_venta=5, id_producto=86, nombre_producto='Jugo en Polvo Limón', cantidad=4, precio_unitario=4090.0, importe=16360.0, fecha=datetime.datetime(2024, 6, 11, 0, 0))])

# %%
## Obtener una venta por ID 2
venta_2 = venta_serv.get_by_id_venta(2)
print(venta_2)
# Out:
# VentaModel(id_venta=2, fecha=datetime.datetime(2024, 3, 17, 0, 0), id_cliente=49, nombre_cliente='Olivia Gomez', email='olivia.gomez@mail.com', medio_pago='qr', ciudad='Rio Cuarto', importe=34186.0, detalle=[DetalleVentaModel(id_venta=2, id_producto=82, nombre_producto='Aceitunas Negras 200g', cantidad=5, precio_unitario=2394.0, importe=11970.0, fecha=datetime.datetime(2024, 3, 17, 0, 0)), DetalleVentaModel(id_venta=2, id_producto=39, nombre_producto='Helado Vainilla 1L', cantidad=5, precio_unitario=469.0, importe=2345.0, fecha=datetime.datetime(2024, 3, 17, 0, 0)), DetalleVentaModel(id_venta=2, id_producto=70, nombre_producto='Fernet 750ml', cantidad=2, precio_unitario=4061.0, importe=8122.0, fecha=datetime.datetime(2024, 3, 17, 0, 0)), DetalleVentaModel(id_venta=2, id_producto=22, nombre_producto='Medialunas de Manteca', cantidad=1, precio_unitario=2069.0, importe=2069.0, fecha=datetime.datetime(2024, 3, 17, 0, 0)), DetalleVentaModel(id_venta=2, id_producto=79, nombre_producto='Hamburguesas Congeladas x4', cantidad=4, precio_unitario=2420.0, importe=9680.0, fecha=datetime.datetime(2024, 3, 17, 0, 0))])

# %%
## Si se prefiere en Formato JSON (muy util para APIs web)
print(venta_2.to_json())
# Out:
# {
#     "id_venta": 2,
#     "fecha": "2024-03-17 00:00:00",
#     "id_cliente": 49,
#     "nombre_cliente": "Olivia Gomez",
#     "email": "olivia.gomez@mail.com",
#     "medio_pago": "qr",
#     "importe": 34186.0,
#     "detalle": [
#         {
#             "id_venta": 2,
#             "id_producto": 82,
#             "nombre_producto": "Aceitunas Negras 200g",
#             "cantidad": 5,
#             "precio_unitario": 2394.0,
#             "importe": 11970.0,
#             "fecha": "2024-03-17 00:00:00"
#         },
#         {
#             "id_venta": 2,
#             "id_producto": 39,
#             "nombre_producto": "Helado Vainilla 1L",
#             "cantidad": 5,
#             "precio_unitario": 469.0,
#             "importe": 2345.0,
#             "fecha": "2024-03-17 00:00:00"
#         },
#         {
#             "id_venta": 2,
#             "id_producto": 70,
#             "nombre_producto": "Fernet 750ml",
#             "cantidad": 2,
#             "precio_unitario": 4061.0,
#             "importe": 8122.0,
#             "fecha": "2024-03-17 00:00:00"
#         },
#         {
#             "id_venta": 2,
#             "id_producto": 22,
#             "nombre_producto": "Medialunas de Manteca",
#             "cantidad": 1,
#             "precio_unitario": 2069.0,
#             "importe": 2069.0,
#             "fecha": "2024-03-17 00:00:00"
#         },
#         {
#             "id_venta": 2,
#             "id_producto": 79,
#             "nombre_producto": "Hamburguesas Congeladas x4",
#             "cantidad": 4,
#             "precio_unitario": 2420.0,
#             "importe": 9680.0,
#             "fecha": "2024-03-17 00:00:00"
#         }
#     ]
# }

# %%
## Extracción de los primeros 5 productos de la base de datos

producto_serv = app.productos_service

for producto in producto_serv.get_all()[:5]:
    print(producto)
# Out:
# ProductoModel(id_producto=1, nombre_producto='Coca Cola 1.5L', categoria='Alimentos', precio_unitario=2347.0, ventas=[DetalleVentaModel(id_venta=43, id_producto=1, nombre_producto='Coca Cola 1.5L', cantidad=5, precio_unitario=2347.0, importe=11735.0, fecha=datetime.datetime(2024, 2, 18, 0, 0)), DetalleVentaModel(id_venta=86, id_producto=1, nombre_producto='Coca Cola 1.5L', cantidad=4, precio_unitario=2347.0, importe=9388.0, fecha=datetime.datetime(2024, 1, 10, 0, 0))])
# ProductoModel(id_producto=2, nombre_producto='Pepsi 1.5L', categoria='Alimentos', precio_unitario=4973.0, ventas=[DetalleVentaModel(id_venta=3, id_producto=2, nombre_producto='Pepsi 1.5L', cantidad=2, precio_unitario=4973.0, importe=9946.0, fecha=datetime.datetime(2024, 1, 13, 0, 0)), DetalleVentaModel(id_venta=63, id_producto=2, nombre_producto='Pepsi 1.5L', cantidad=2, precio_unitario=4973.0, importe=9946.0, fecha=datetime.datetime(2024, 6, 19, 0, 0)), DetalleVentaModel(id_venta=75, id_producto=2, nombre_producto='Pepsi 1.5L', cantidad=5, precio_unitario=4973.0, importe=24865.0, fecha=datetime.datetime(2024, 5, 23, 0, 0))])
# ProductoModel(id_producto=3, nombre_producto='Sprite 1.5L', categoria='Alimentos', precio_unitario=4964.0, ventas=[DetalleVentaModel(id_venta=75, id_producto=3, nombre_producto='Sprite 1.5L', cantidad=4, precio_unitario=4964.0, importe=19856.0, fecha=datetime.datetime(2024, 5, 23, 0, 0))])
# ProductoModel(id_producto=4, nombre_producto='Fanta Naranja 1.5L', categoria='Alimentos', precio_unitario=2033.0, ventas=[DetalleVentaModel(id_venta=4, id_producto=4, nombre_producto='Fanta Naranja 1.5L', cantidad=2, precio_unitario=2033.0, importe=4066.0, fecha=datetime.datetime(2024, 2, 27, 0, 0)), DetalleVentaModel(id_venta=18, id_producto=4, nombre_producto='Fanta Naranja 1.5L', cantidad=5, precio_unitario=2033.0, importe=10165.0, fecha=datetime.datetime(2024, 6, 11, 0, 0)), DetalleVentaModel(id_venta=64, id_producto=4, nombre_producto='Fanta Naranja 1.5L', cantidad=2, precio_unitario=2033.0, importe=4066.0, fecha=datetime.datetime(2024, 3, 7, 0, 0)), DetalleVentaModel(id_venta=97, id_producto=4, nombre_producto='Fanta Naranja 1.5L', cantidad=3, precio_unitario=2033.0, importe=6099.0, fecha=datetime.datetime(2024, 6, 16, 0, 0)), DetalleVentaModel(id_venta=105, id_producto=4, nombre_producto='Fanta Naranja 1.5L', cantidad=4, precio_unitario=2033.0, importe=8132.0, fecha=datetime.datetime(2024, 2, 6, 0, 0))])
# ProductoModel(id_producto=5, nombre_producto='Agua Mineral 500ml', categoria='Alimentos', precio_unitario=4777.0, ventas=[DetalleVentaModel(id_venta=38, id_producto=5, nombre_producto='Agua Mineral 500ml', cantidad=3, precio_unitario=4777.0, importe=14331.0, fecha=datetime.datetime(2024, 5, 29, 0, 0)), DetalleVentaModel(id_venta=83, id_producto=5, nombre_producto='Agua Mineral 500ml', cantidad=2, precio_unitario=4777.0, importe=9554.0, fecha=datetime.datetime(2024, 5, 28, 0, 0)), DetalleVentaModel(id_venta=107, id_producto=5, nombre_producto='Agua Mineral 500ml', cantidad=4, precio_unitario=4777.0, importe=19108.0, fecha=datetime.datetime(2024, 5, 21, 0, 0))])

# %%
producto1 = producto_serv.get_by_id(1)

print(producto1.ventas)
print(producto1.total_ventas())
# Out:
# [DetalleVentaModel(id_venta=43, id_producto=1, nombre_producto='Coca Cola 1.5L', cantidad=5, precio_unitario=2347.0, importe=11735.0, fecha=datetime.datetime(2024, 2, 18, 0, 0)), DetalleVentaModel(id_venta=86, id_producto=1, nombre_producto='Coca Cola 1.5L', cantidad=4, precio_unitario=2347.0, importe=9388.0, fecha=datetime.datetime(2024, 1, 10, 0, 0))]
# {'cantidad': 9, 'importe': 21123.0}

# %%
ventas_ciudades = venta_serv.get_ventas_por_ciudad()
print(ventas_ciudades)
# Out:
# [{'ciudad': 'RIO CUARTO', 'departamento': 'RIO CUARTO', 'importe': 792203.0}, {'ciudad': 'ALTA GRACIA', 'departamento': 'SANTA MARIA', 'importe': 481504.0}, {'ciudad': 'CORDOBA', 'departamento': 'CAPITAL', 'importe': 481482.0}, {'ciudad': 'CARLOS PAZ', 'departamento': 'PUNILLA', 'importe': 353852.0}, {'ciudad': 'VILLA MARIA', 'departamento': 'GENERAL SAN MARTIN', 'importe': 313350.0}, {'ciudad': 'MENDIOLAZA', 'departamento': 'COLON', 'importe': 229026.0}]
